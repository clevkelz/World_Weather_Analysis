# %%
# Import the dependencies. - OK Matches UP

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations. - OK Matches Up

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.00, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. - OK Matches Up
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations. - OK Matches up
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# -76.99895964072334 -62.936182058337835
# -86.72598156874129 75.4351512852559
# 19.49879630569734 137.04913039821542
# 37.22628268345292 -48.35305199238337
# -41.71909019269414 -149.48673290009378
# 1.6529394142851714 -156.04685982918116
# 60.92275717033334 92.0282071697556
# -43.76697141977331 -54.133444706018935
# -4.526584898536612 166.11171144509547
# 39.61040887245204 -25.597357822726792
# 15.014326738279067 -52.774343761528854
# -75.2952365388497 -150.05609035205023
# 70.05882255343417 31.03220737038569
# 27.780640253342185 -83.6382742070904
# 0.5431793852450397 99.23147383770578
# 65.63097454610497 152.38918576455222
# -79.86849430321926 -86.24907720441124
# 14.789615739479743 25.738388255520874
# 1.8514928238891173 129.61470337636086
# -10.56486432653547 143.75224667570643
# -43.786297552490225 53.380427285901646
# 70.0756330388451 78.3779769333949
# -1.5758260068721626 38.29604094455868
# 78.81544648925373 25.86085585950471
# 81.25893501043365 72.42167088446513
# ...

# %%
# Import citipy - OK matches up

from citipy import citipy

# %%
# Import the requests library. - THIS WAS NOT REALLY SPELT OUT IN THE INSTRUCTIONS
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call. THIS WAS ALSO NOT REALLY CLEAR FROM THE INSTRUCTIONS


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities. - OK matches up
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 598

# %%
# Import the time library and the datetime module from the datetime library - this is ok
import time
from datetime import datetime

# %%
# Import the requests library. - THIS WAS NOT REALLY SPELT OUT IN THE INSTRUCTIONS
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call. THIS WAS ALSO NOT REALLY CLEAR FROM THE INSTRUCTIONS


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data. - this is ok
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | nishihara
# Processing Record 4 of Set 1 | torbay
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | teya
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | lata
# Processing Record 10 of Set 1 | praia da vitoria
# Processing Record 11 of Set 1 | bathsheba
# Processing Record 12 of Set 1 | vardo
# Processing Record 13 of Set 1 | seminole
# Processing Record 14 of Set 1 | sibolga
# Processing Record 15 of Set 1 | zyryanka
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | kutum
# Processing Record 18 of Set 1 | ternate
# Processing Record 19 of Set 1 | daru
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | tazovskiy
# Processing Record 22 of Set 1 | kitui
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        
_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 545     True
# 546     True
# 547     True
# 548     True
# 549     True
# Name: Lat, Length: 550, dtype: bool

# %%
updated_city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 2      Nishihara      JP  2022-07-14 01:31:54  26.1842  127.7558     87.08
# 3         Torbay      CA  2022-07-14 01:31:55  47.6666  -52.7314     66.97
# 5           Hilo      US  2022-07-14 01:31:55  19.7297 -155.0900     81.28
# 6           Teya      RU  2022-07-14 01:31:56  60.3778   92.6267     59.85
# 8           Lata      PT  2022-07-14 01:31:56  40.1629   -8.3327     77.07
# ..           ...     ...                  ...      ...       ...       ...
# 545  Morgan City      US  2022-07-14 01:45:55  29.6994  -91.2068     81.01
# 546   Nouadhibou      MR  2022-07-14 01:45:55  20.9310  -17.0347     69.78
# 547      Parrita      CR  2022-07-14 01:45:56   9.5201  -84.3225     76.17
# 548      Phalodi      IN  2022-07-14 01:45:56  27.1333   72.3667     82.04
# 549     Morehead      US  2022-07-14 01:45:56  37.2711  -87.1764     75.85
#
#      Humidity  Cloudiness  Wind Speed
# ...

# %%
updated_city_data_df.loc[(city_data_df["Lat"]) >= 0].head()
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 2  Nishihara      JP  2022-07-14 01:31:54  26.1842  127.7558     87.08
# 3     Torbay      CA  2022-07-14 01:31:55  47.6666  -52.7314     66.97
# 5       Hilo      US  2022-07-14 01:31:55  19.7297 -155.0900     81.28
# 6       Teya      RU  2022-07-14 01:31:56  60.3778   92.6267     59.85
# 8       Lata      PT  2022-07-14 01:31:56  40.1629   -8.3327     77.07
#
#    Humidity  Cloudiness  Wind Speed
# 2        79          75        5.75
# 3        88         100       17.27
# 5        91         100       12.66
# 6        49          68        3.24
# 8        28          41        3.83

# %%
# Create Northern Hemisphere DataFrame and Southern Hemisphere DataFrame
northern_hemi_df = updated_city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = updated_city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# %%
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# y = -0.39x + 86.6
# The p-value is: 0.000
# The r-value is: -0.635

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# %%
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# y = 0.73x + 78.71
# The p-value is: 0.000
# The r-value is: 0.808

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# %%
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# y = -0.14x + 75.56
# The p-value is: 0.007
# The r-value is: -0.138

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# %%
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# y = -0.04x + 73.24
# The p-value is: 0.672
# The r-value is: -0.033

# %%
# Linear regression on the Northern Hemisphere for Cloudiness
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Humidity',(0,100))

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# %%
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# y = -0.16x + 66.85
# The p-value is: 0.111
# The r-value is: -0.082

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# %%
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# y = -0.24x + 45.34
# The p-value is: 0.266
# The r-value is: -0.086

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# %%
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
# Out:
# y = 0.01x + 7.36
# The p-value is: 0.476
# The r-value is: 0.037

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# %%
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
print(f"The r-value is: {r_value:.3f}")
